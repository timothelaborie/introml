# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np
import seaborn as sns
import pandas as pd

rcParams['figure.figsize'] = 12,8
sns.set(rc={'figure.figsize':(12,8)})

# %%
X = pd.read_csv("pretrain_features.csv.zip").iloc[:, 2:]
Y = pd.read_csv("pretrain_labels.csv.zip").iloc[:, 1:]
X["lumo_energy"] = Y["lumo_energy"]

# %%
test = pd.read_csv("pretrain_labels.csv.zip")

# %%
# test["smiles"][0]
test
# Out:
#           Id  lumo_energy
# 0          0    -3.111521
# 1          1    -3.219118
# 2          2    -3.114145
# 3          3    -3.161867
# 4          4    -3.687744
# ...      ...          ...
# 49995  49995    -3.531096
# 49996  49996    -3.726209
# 49997  49997    -2.701048
# 49998  49998    -3.516759
# 49999  49999    -3.410109
#
# [50000 rows x 2 columns]

# %%
fig, ax = plt.subplots()
sns.kdeplot(X["lumo_energy"], ax=ax)
ax.set_xlim(-5,5)
ax.set_xticks(range(-5,5))
plt.show()

# %%
X = pd.read_csv("train_features.csv.zip").iloc[:, 2:]
Y = pd.read_csv("train_labels.csv.zip").iloc[:, 1:]
X["homo_lumo_gap"] = Y["homo_lumo_gap"]

# %%
# sns.displot(data = X, x = 'homo_lumo_gap', kind = 'kde')
a4_dims = (10, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.kdeplot(X["homo_lumo_gap"], ax=ax)
ax.set_xlim(0,5)
ax.set_xticks(range(0,5))
plt.show()

# %%
a4_dims = (10, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.kdeplot(pd.read_csv("analysis/best.csv")["y"], ax=ax)
ax.set_xlim(0,5)
ax.set_xticks(range(0,5))
plt.show()

# %%
#keep all data when plotting first, so you can find outliers and decide what to do with them
# sns.regplot(data = X, x = 'feature_0000', y = 'lumo_energy', scatter_kws = {'color': 'pink'})
