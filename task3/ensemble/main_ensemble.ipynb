# %%
from  __future__ import absolute_import
from __future__ import print_function
from keras.layers import *
from keras.models import Model, load_model
from keras.preprocessing.image import load_img, img_to_array
import tensorflow as tf
from keras import backend as K
import tensorflow_hub as hub
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import logging
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow_hub as hub
from PIL import Image
import pickle
import shutil
import matplotlib.pyplot as plt
import os
import random
import tensorflow as tf
from pathlib import Path
from keras import applications
from keras import layers
from keras import losses
from keras import optimizers
from keras import metrics
from keras import Model
from keras.applications import resnet
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
import tensorflow_addons as tfa
from keras.regularizers import l2
from keras.activations import *
from DistanceLayer import DistanceLayer
from SiameseModel import SiameseModel
import copy
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

print(tf.__version__)


# batch_size = 19
batch_size = 23
# Out:
# 2.8.0

# %%
train_triplets = np.loadtxt('./train_triplets_split.txt', dtype=str,delimiter = ' ')
val_triplets = np.loadtxt('./val_triplets_split.txt', dtype=str,delimiter = ' ')

# triplets1 = copy.deepcopy(train_triplets)[0:2438]
# triplets2 = copy.deepcopy(train_triplets)[2438:2438*2]
# triplets3 = copy.deepcopy(train_triplets)[2438*2:2438*3]

# print(triplets1)
# print(triplets3)
# print(len(triplets2))
# print(len(triplets3))

# %%
for file in ["clip","resnet","xl","vit"]:
# for file in ["xl"]:

    features = {}
    # file = "clip"
    with open('features_' + file + '.pickle', 'rb') as handle:
        features = pickle.load(handle)

    feature_dim = features["02461"].shape[0]

    #convert the features dictionary to a tensorflow hash table
    keys = tf.constant([key for key in features.keys()])
    values = tf.constant([val for val in features.values()])

    table = tf.lookup.experimental.DenseHashTable(
        value_dtype=tf.float32,
        key_dtype=tf.string,
        empty_key="empty_key",
        deleted_key="deleted_key",
        default_value=[-1]*feature_dim,
        )

    table.insert(keys, values)

    @tf.function
    def load_image(inputs):
        filenames = inputs
        anchor = table[filenames[0]]
        positive = table[filenames[1]]
        negative = table[filenames[2]]
        output = (anchor,positive,negative)
        
        return output



    val_dataset = tf.data.Dataset.from_tensor_slices(val_triplets)
    val_dataset = val_dataset.map(load_image).cache().batch(100).prefetch(20)

    split_id = 1
    n = np.array(train_triplets).shape[0]//3
    for split in [train_triplets[i:i + n] for i in range(0, len(train_triplets)-1, n)]:
    # for split in [train_triplets for i in range(0, 3)]:
    # for split in [train_triplets]:

        print("file: ", file, "split: ", split_id, " split size: ", len(split))
        # print(split[0])
        # print(split[1])
        # print(split[2])
        embedding = tf.keras.Sequential([
            Input(shape=(feature_dim,)),
            # BatchNormalization(),
            Dense(8192, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.001)),
            # Dropout(0.6),
            BatchNormalization(),
            Dense(8192, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.001)),
            # Dropout(0.6),
            BatchNormalization(),
            Lambda(lambda  x: K.l2_normalize(x,axis=1))
        ])

        anchor_input = layers.Input(name="anchor", shape=(feature_dim))
        positive_input = layers.Input(name="positive", shape=(feature_dim))
        negative_input = layers.Input(name="negative", shape=(feature_dim))

        distances = DistanceLayer()(
            embedding(anchor_input),
            embedding(positive_input),
            embedding(negative_input),
        )

        model = Model(
            inputs=[anchor_input, positive_input, negative_input], outputs=distances
        )

        # model.summary()



        train_dataset = tf.data.Dataset.from_tensor_slices(split)
        
        count = np.array(split).shape[0]
        # print(count)
        # print(np.array(val_triplets).shape[0])




        train_dataset = train_dataset.map(load_image).cache().shuffle(buffer_size=1000).batch(batch_size).prefetch(20)
        

        model = SiameseModel(model,margin=0.5,scale=64)
        model.compile(optimizer=tf.keras.optimizers.Adam(0.000001))


        train_steps_per_epoch = int(count/batch_size)
        # checkpoint_filepath = './checkpoints/checkpoint-{epoch}/'
        #save checkpoint after every epoch
        # callback = ModelCheckpoint(
        #     filepath=checkpoint_filepath,
        #     # save_weights_only=True,
        # )
        callback = EarlyStopping(monitor='val_accuracy', patience=3,restore_best_weights=True)


        model.fit(train_dataset, epochs=100,steps_per_epoch=train_steps_per_epoch,batch_size=batch_size,callbacks=[callback],validation_data=val_dataset)
        # print("training")
        # model.fit(train_dataset, epochs=3,steps_per_epoch=train_steps_per_epoch,batch_size=batch_size,validation_data=val_dataset)
        # print("trained")


        #predict distances and save them to a file

        dataset = np.loadtxt('./val_triplets_split_shuffled.txt', dtype=str,delimiter = ' ')
        # print(dataset.shape)
        dataset = tf.data.Dataset.from_tensor_slices(dataset)
        dataset = dataset.map(load_image).batch(100)
        left = []
        right = []
        for triplet in iter(dataset):
            anchor = triplet[0]
            positive = triplet[1]
            negative = triplet[2]
            distances = model.predict([anchor,positive,negative])
            left_distances = distances[0]
            right_distances = distances[1]
            s = np.array(left_distances).shape[0]
            # print(s)
            for i in range(s):
                left.append(distances[0][i])
                right.append(distances[1][i])



        df = pd.read_csv("val_distances.csv",index_col=0)
        df['anchor_left_distance_'+file+'_'+str(split_id)] = left
        df['anchor_right_distance_'+file+'_'+str(split_id)] = right
        df.to_csv('val_distances.csv')

        split_id += 1

        del model
        del embedding
        del anchor_input
        del positive_input
        del negative_input
        del callback
        del train_dataset
        del dataset
        # del val_dataset
# Out:
# file:  clip split:  1  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 66s 604ms/step - loss: 0.4544 - val_accuracy: 0.6975
# Epoch 2/100
# 106/106 [==============================] - 52s 487ms/step - loss: 0.4220 - val_accuracy: 0.7283
# Epoch 3/100
# 106/106 [==============================] - 49s 462ms/step - loss: 0.3669 - val_accuracy: 0.7422
# Epoch 4/100
# 106/106 [==============================] - 47s 442ms/step - loss: 0.3160 - val_accuracy: 0.7449
# Epoch 5/100
# 106/106 [==============================] - 46s 435ms/step - loss: 0.2923 - val_accuracy: 0.7498
# Epoch 6/100
# 106/106 [==============================] - 47s 443ms/step - loss: 0.2799 - val_accuracy: 0.7510
# Epoch 7/100
# 106/106 [==============================] - 48s 450ms/step - loss: 0.2708 - val_accuracy: 0.7532
# Epoch 8/100
# 106/106 [==============================] - 32s 305ms/step - loss: 0.2630 - val_accuracy: 0.7529
# Epoch 9/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2556 - val_accuracy: 0.7545
# Epoch 10/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2485 - val_accuracy: 0.7545
# Epoch 11/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2415 - val_accuracy: 0.7564
# Epoch 12/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2349 - val_accuracy: 0.7573
# Epoch 13/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2284 - val_accuracy: 0.7569
# Epoch 14/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2220 - val_accuracy: 0.7579
# Epoch 15/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2160 - val_accuracy: 0.7584
# Epoch 16/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2099 - val_accuracy: 0.7575
# Epoch 17/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2041 - val_accuracy: 0.7584
# Epoch 18/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.1984 - val_accuracy: 0.7588
# Epoch 19/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.1927 - val_accuracy: 0.7588
# Epoch 20/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.1872 - val_accuracy: 0.7589
# Epoch 21/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.1818 - val_accuracy: 0.7579
# Epoch 22/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.1765 - val_accuracy: 0.7589
# Epoch 23/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.1713 - val_accuracy: 0.7587
# file:  clip split:  2  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 6s 47ms/step - loss: 0.4538 - val_accuracy: 0.6947
# Epoch 2/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.4231 - val_accuracy: 0.7237
# Epoch 3/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.3736 - val_accuracy: 0.7390
# Epoch 4/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.3238 - val_accuracy: 0.7455
# Epoch 5/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2985 - val_accuracy: 0.7476
# Epoch 6/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2862 - val_accuracy: 0.7504
# Epoch 7/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2775 - val_accuracy: 0.7524
# Epoch 8/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2700 - val_accuracy: 0.7544
# Epoch 9/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2629 - val_accuracy: 0.7542
# Epoch 10/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2561 - val_accuracy: 0.7548
# Epoch 11/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2495 - val_accuracy: 0.7563
# Epoch 12/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2430 - val_accuracy: 0.7553
# Epoch 13/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2366 - val_accuracy: 0.7563
# Epoch 14/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2302 - val_accuracy: 0.7567
# Epoch 15/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2239 - val_accuracy: 0.7572
# Epoch 16/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2175 - val_accuracy: 0.7575
# Epoch 17/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2112 - val_accuracy: 0.7569
# Epoch 18/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2052 - val_accuracy: 0.7569
# Epoch 19/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.1993 - val_accuracy: 0.7569
# file:  clip split:  3  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 6s 48ms/step - loss: 0.4572 - val_accuracy: 0.6924
# Epoch 2/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.4286 - val_accuracy: 0.7224
# Epoch 3/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.3817 - val_accuracy: 0.7395
# Epoch 4/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.3334 - val_accuracy: 0.7484
# Epoch 5/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.3091 - val_accuracy: 0.7521
# Epoch 6/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2958 - val_accuracy: 0.7549
# Epoch 7/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2866 - val_accuracy: 0.7555
# Epoch 8/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2784 - val_accuracy: 0.7559
# Epoch 9/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2711 - val_accuracy: 0.7557
# Epoch 10/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2640 - val_accuracy: 0.7569
# Epoch 11/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2571 - val_accuracy: 0.7568
# Epoch 12/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2501 - val_accuracy: 0.7559
# Epoch 13/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2433 - val_accuracy: 0.7560
# file:  resnet split:  1  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 6s 52ms/step - loss: 0.4526 - val_accuracy: 0.6806
# Epoch 2/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.4228 - val_accuracy: 0.7059
# Epoch 3/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.3795 - val_accuracy: 0.7233
# Epoch 4/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.3344 - val_accuracy: 0.7308
# Epoch 5/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.3048 - val_accuracy: 0.7366
# Epoch 6/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2866 - val_accuracy: 0.7393
# Epoch 7/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2734 - val_accuracy: 0.7411
# Epoch 8/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.2624 - val_accuracy: 0.7411
# Epoch 9/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2530 - val_accuracy: 0.7433
# Epoch 10/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2441 - val_accuracy: 0.7451
# Epoch 11/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2359 - val_accuracy: 0.7460
# Epoch 12/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2284 - val_accuracy: 0.7461
# Epoch 13/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2210 - val_accuracy: 0.7465
# Epoch 14/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2139 - val_accuracy: 0.7462
# Epoch 15/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2074 - val_accuracy: 0.7469
# Epoch 16/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2010 - val_accuracy: 0.7466
# Epoch 17/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.1947 - val_accuracy: 0.7481
# Epoch 18/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.1887 - val_accuracy: 0.7468
# Epoch 19/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.1829 - val_accuracy: 0.7480
# Epoch 20/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.1773 - val_accuracy: 0.7469
# file:  resnet split:  2  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 6s 53ms/step - loss: 0.4568 - val_accuracy: 0.6875
# Epoch 2/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.4272 - val_accuracy: 0.7097
# Epoch 3/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.3829 - val_accuracy: 0.7248
# Epoch 4/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.3404 - val_accuracy: 0.7352
# Epoch 5/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.3125 - val_accuracy: 0.7370
# Epoch 6/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2948 - val_accuracy: 0.7419
# Epoch 7/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2822 - val_accuracy: 0.7433
# Epoch 8/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2718 - val_accuracy: 0.7457
# Epoch 9/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2621 - val_accuracy: 0.7478
# Epoch 10/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2536 - val_accuracy: 0.7496
# Epoch 11/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2455 - val_accuracy: 0.7506
# Epoch 12/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2379 - val_accuracy: 0.7504
# Epoch 13/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2305 - val_accuracy: 0.7518
# Epoch 14/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2233 - val_accuracy: 0.7533
# Epoch 15/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2163 - val_accuracy: 0.7529
# Epoch 16/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2097 - val_accuracy: 0.7533
# Epoch 17/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2033 - val_accuracy: 0.7548
# Epoch 18/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.1970 - val_accuracy: 0.7548
# Epoch 19/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.1910 - val_accuracy: 0.7551
# Epoch 20/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.1849 - val_accuracy: 0.7552
# Epoch 21/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.1790 - val_accuracy: 0.7545
# Epoch 22/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.1733 - val_accuracy: 0.7544
# Epoch 23/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.1677 - val_accuracy: 0.7552
# file:  resnet split:  3  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 6s 52ms/step - loss: 0.4580 - val_accuracy: 0.6826
# Epoch 2/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.4318 - val_accuracy: 0.7062
# Epoch 3/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.3928 - val_accuracy: 0.7213
# Epoch 4/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.3510 - val_accuracy: 0.7332
# Epoch 5/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.3224 - val_accuracy: 0.7387
# Epoch 6/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.3042 - val_accuracy: 0.7419
# Epoch 7/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2916 - val_accuracy: 0.7445
# Epoch 8/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2812 - val_accuracy: 0.7461
# Epoch 9/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2719 - val_accuracy: 0.7482
# Epoch 10/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2633 - val_accuracy: 0.7497
# Epoch 11/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2552 - val_accuracy: 0.7512
# Epoch 12/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2473 - val_accuracy: 0.7517
# Epoch 13/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2398 - val_accuracy: 0.7536
# Epoch 14/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2328 - val_accuracy: 0.7537
# Epoch 15/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2258 - val_accuracy: 0.7540
# Epoch 16/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2192 - val_accuracy: 0.7548
# Epoch 17/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2128 - val_accuracy: 0.7547
# Epoch 18/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2063 - val_accuracy: 0.7559
# Epoch 19/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2002 - val_accuracy: 0.7555
# Epoch 20/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.1942 - val_accuracy: 0.7559
# Epoch 21/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.1884 - val_accuracy: 0.7553
# file:  xl split:  1  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 6s 49ms/step - loss: 0.4574 - val_accuracy: 0.6806
# Epoch 2/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.4376 - val_accuracy: 0.6996
# Epoch 3/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.4119 - val_accuracy: 0.7117
# Epoch 4/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3802 - val_accuracy: 0.7216
# Epoch 5/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3478 - val_accuracy: 0.7268
# Epoch 6/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3213 - val_accuracy: 0.7284
# Epoch 7/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.3011 - val_accuracy: 0.7277
# Epoch 8/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2864 - val_accuracy: 0.7302
# Epoch 9/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2746 - val_accuracy: 0.7334
# Epoch 10/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2645 - val_accuracy: 0.7327
# Epoch 11/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2554 - val_accuracy: 0.7334
# Epoch 12/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2470 - val_accuracy: 0.7332
# file:  xl split:  2  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 6s 49ms/step - loss: 0.4591 - val_accuracy: 0.6768
# Epoch 2/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.4407 - val_accuracy: 0.6954
# Epoch 3/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.4168 - val_accuracy: 0.7097
# Epoch 4/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3860 - val_accuracy: 0.7193
# Epoch 5/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3524 - val_accuracy: 0.7286
# Epoch 6/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3249 - val_accuracy: 0.7320
# Epoch 7/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3042 - val_accuracy: 0.7323
# Epoch 8/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2884 - val_accuracy: 0.7336
# Epoch 9/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2757 - val_accuracy: 0.7339
# Epoch 10/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2650 - val_accuracy: 0.7364
# Epoch 11/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2555 - val_accuracy: 0.7371
# Epoch 12/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2466 - val_accuracy: 0.7381
# Epoch 13/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2383 - val_accuracy: 0.7390
# Epoch 14/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2303 - val_accuracy: 0.7398
# Epoch 15/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2226 - val_accuracy: 0.7407
# Epoch 16/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2151 - val_accuracy: 0.7399
# Epoch 17/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2077 - val_accuracy: 0.7403
# Epoch 18/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2005 - val_accuracy: 0.7402
# file:  xl split:  3  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 6s 49ms/step - loss: 0.4643 - val_accuracy: 0.6745
# Epoch 2/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.4474 - val_accuracy: 0.6936
# Epoch 3/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.4257 - val_accuracy: 0.7090
# Epoch 4/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.3981 - val_accuracy: 0.7203
# Epoch 5/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3663 - val_accuracy: 0.7272
# Epoch 6/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3378 - val_accuracy: 0.7296
# Epoch 7/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3170 - val_accuracy: 0.7332
# Epoch 8/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3019 - val_accuracy: 0.7350
# Epoch 9/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2898 - val_accuracy: 0.7344
# Epoch 10/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2794 - val_accuracy: 0.7363
# Epoch 11/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2702 - val_accuracy: 0.7366
# Epoch 12/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2617 - val_accuracy: 0.7368
# Epoch 13/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2536 - val_accuracy: 0.7389
# Epoch 14/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2457 - val_accuracy: 0.7405
# Epoch 15/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2380 - val_accuracy: 0.7423
# Epoch 16/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2304 - val_accuracy: 0.7415
# Epoch 17/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.2231 - val_accuracy: 0.7431
# Epoch 18/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2159 - val_accuracy: 0.7434
# Epoch 19/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.2088 - val_accuracy: 0.7434
# Epoch 20/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2018 - val_accuracy: 0.7437
# Epoch 21/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.1950 - val_accuracy: 0.7442
# Epoch 22/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.1881 - val_accuracy: 0.7434
# Epoch 23/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.1815 - val_accuracy: 0.7449
# Epoch 24/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.1750 - val_accuracy: 0.7453
# Epoch 25/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.1686 - val_accuracy: 0.7454
# Epoch 26/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.1624 - val_accuracy: 0.7447
# Epoch 27/100
# 106/106 [==============================] - 5s 46ms/step - loss: 0.1563 - val_accuracy: 0.7438
# Epoch 28/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.1504 - val_accuracy: 0.7449
# file:  vit split:  1  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 6s 47ms/step - loss: 0.4589 - val_accuracy: 0.6450
# Epoch 2/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.4429 - val_accuracy: 0.6658
# Epoch 3/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.4256 - val_accuracy: 0.6812
# Epoch 4/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.4066 - val_accuracy: 0.6962
# Epoch 5/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.3858 - val_accuracy: 0.7066
# Epoch 6/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.3642 - val_accuracy: 0.7113
# Epoch 7/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.3434 - val_accuracy: 0.7156
# Epoch 8/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.3254 - val_accuracy: 0.7186
# Epoch 9/100
# 106/106 [==============================] - 5s 44ms/step - loss: 0.3108 - val_accuracy: 0.7182
# Epoch 10/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2989 - val_accuracy: 0.7190
# Epoch 11/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2887 - val_accuracy: 0.7200
# Epoch 12/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2796 - val_accuracy: 0.7201
# Epoch 13/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2712 - val_accuracy: 0.7207
# Epoch 14/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2633 - val_accuracy: 0.7227
# Epoch 15/100
# 106/106 [==============================] - 5s 44ms/step - loss: 0.2556 - val_accuracy: 0.7227
# Epoch 16/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.2484 - val_accuracy: 0.7233
# Epoch 17/100
# 106/106 [==============================] - 5s 44ms/step - loss: 0.2414 - val_accuracy: 0.7231
# Epoch 18/100
# 106/106 [==============================] - 5s 44ms/step - loss: 0.2345 - val_accuracy: 0.7229
# Epoch 19/100
# 106/106 [==============================] - 5s 44ms/step - loss: 0.2277 - val_accuracy: 0.7217
# file:  vit split:  2  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 6s 47ms/step - loss: 0.4528 - val_accuracy: 0.6436
# Epoch 2/100
# 106/106 [==============================] - 5s 45ms/step - loss: 0.4366 - val_accuracy: 0.6683
# Epoch 3/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.4191 - val_accuracy: 0.6830
# Epoch 4/100
# 106/106 [==============================] - 5s 47ms/step - loss: 0.3997 - val_accuracy: 0.6939
# Epoch 5/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.3786 - val_accuracy: 0.7042
# Epoch 6/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.3567 - val_accuracy: 0.7122
# Epoch 7/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.3362 - val_accuracy: 0.7148
# Epoch 8/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.3184 - val_accuracy: 0.7174
# Epoch 9/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.3032 - val_accuracy: 0.7194
# Epoch 10/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2904 - val_accuracy: 0.7217
# Epoch 11/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2795 - val_accuracy: 0.7243
# Epoch 12/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.2701 - val_accuracy: 0.7264
# Epoch 13/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2617 - val_accuracy: 0.7263
# Epoch 14/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2538 - val_accuracy: 0.7265
# Epoch 15/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2464 - val_accuracy: 0.7268
# Epoch 16/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2393 - val_accuracy: 0.7260
# Epoch 17/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.2323 - val_accuracy: 0.7271
# Epoch 18/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.2256 - val_accuracy: 0.7273
# Epoch 19/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2190 - val_accuracy: 0.7276
# Epoch 20/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2125 - val_accuracy: 0.7276
# Epoch 21/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.2062 - val_accuracy: 0.7271
# Epoch 22/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.2000 - val_accuracy: 0.7263
# file:  vit split:  3  split size:  2438
# Epoch 1/100
# 106/106 [==============================] - 6s 51ms/step - loss: 0.4587 - val_accuracy: 0.6398
# Epoch 2/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.4430 - val_accuracy: 0.6654
# Epoch 3/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.4263 - val_accuracy: 0.6825
# Epoch 4/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.4081 - val_accuracy: 0.6979
# Epoch 5/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.3887 - val_accuracy: 0.7071
# Epoch 6/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.3688 - val_accuracy: 0.7137
# Epoch 7/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.3490 - val_accuracy: 0.7178
# Epoch 8/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.3310 - val_accuracy: 0.7199
# Epoch 9/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.3165 - val_accuracy: 0.7208
# Epoch 10/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.3040 - val_accuracy: 0.7224
# Epoch 11/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2931 - val_accuracy: 0.7221
# Epoch 12/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2835 - val_accuracy: 0.7229
# Epoch 13/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2748 - val_accuracy: 0.7228
# Epoch 14/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2666 - val_accuracy: 0.7232
# Epoch 15/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2590 - val_accuracy: 0.7232
# Epoch 16/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2517 - val_accuracy: 0.7236
# Epoch 17/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2447 - val_accuracy: 0.7237
# Epoch 18/100
# 106/106 [==============================] - 5s 51ms/step - loss: 0.2377 - val_accuracy: 0.7244
# Epoch 19/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2310 - val_accuracy: 0.7248
# Epoch 20/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2245 - val_accuracy: 0.7247
# Epoch 21/100
# 106/106 [==============================] - 5s 50ms/step - loss: 0.2179 - val_accuracy: 0.7259
# Epoch 22/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2116 - val_accuracy: 0.7244
# Epoch 23/100
# 106/106 [==============================] - 5s 48ms/step - loss: 0.2052 - val_accuracy: 0.7245
# Epoch 24/100
# 106/106 [==============================] - 5s 49ms/step - loss: 0.1990 - val_accuracy: 0.7240

# %% [markdown]
# # this code was used to initialize the distances file

# %%
# #predict distances and save them to a file
# set_file = "val"
# dataset = np.loadtxt('./'+set_file+'_triplets_split_shuffled.txt', dtype=str,delimiter = ' ')
# print(dataset.shape)
# dataset = tf.data.Dataset.from_tensor_slices(dataset)
# dataset = dataset.map(load_image).batch(100)
# data = []
# for triplet in iter(dataset):
#     anchor = triplet[0]
#     positive = triplet[1]
#     negative = triplet[2]
#     distances = model.predict([anchor,positive,negative])
#     s = np.array(distances).shape[1]
#     for i in range(s):
#         data.append([distances[0][i],distances[1][i]])



# df = pd.DataFrame(data=data,columns=['anchor_left_distance_'+file,'anchor_right_distance_'+file])
# df.to_csv(set_file+'_distances.csv')

# %% [markdown]
# # append other distances

# %%
# #predict distances and save them to a file
# set_file = "val"
# dataset = np.loadtxt('./'+set_file+'_triplets_split_shuffled.txt', dtype=str,delimiter = ' ')
# print(dataset.shape)
# dataset = tf.data.Dataset.from_tensor_slices(dataset)
# dataset = dataset.map(load_image).batch(100)
# left = []
# right = []
# for triplet in iter(dataset):
#     anchor = triplet[0]
#     positive = triplet[1]
#     negative = triplet[2]
#     distances = model.predict([anchor,positive,negative])
#     left_distances = distances[0]
#     right_distances = distances[1]
#     s = np.array(left_distances).shape[0]
#     # print(s)
#     for i in range(s):
#         left.append(distances[0][i])
#         right.append(distances[1][i])



# df = pd.read_csv(set_file+"_distances.csv",index_col=0)
# df['anchor_left_distance_'+file] = left
# df['anchor_right_distance_'+file] = right
# df.to_csv(set_file+'_distances.csv')

# %% [markdown]
# # using clip directly (sucks)

# %%
# #predict distances and save them to a file
# set_file = "val"
# dataset = np.loadtxt('./'+set_file+'_triplets_split_shuffled.txt', dtype=str,delimiter = ' ')
# print(dataset.shape)
# left = []
# right = []
# for triplet in iter(dataset):
#     anchor = triplet[0]
#     positive = triplet[1]
#     negative = triplet[2]
#     # print(np.sum((features[anchor])**2))
#     left.append(np.sum((features[anchor]-features[positive])**2))
#     right.append(np.sum((features[anchor]-features[negative])**2))


# df = pd.read_csv(set_file+"_distances.csv",index_col=0)
# df['anchor_left_distance_clip2'] = left
# df['anchor_right_distance_clip2'] = right
# df.to_csv(set_file+'_distances.csv')
