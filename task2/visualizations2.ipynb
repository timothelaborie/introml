# %%
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

#Loading the dataset
X = pd.read_csv("train_features_improved.csv")
X = pd.DataFrame(scaler.fit_transform(X),columns=X.columns)
# X_small = np.array(df1.iloc[:, :].values,  dtype=float)[::12]
# X = np.array(df1.iloc[:, :].values,  dtype=float)
# df = pd.DataFrame(X, columns = df1.columns)

Y = pd.read_csv("train_labels.csv")
# Y = np.array(labels_df.iloc[:, :].values,  dtype=float)

print(X.shape)
print(Y.shape)
# Out:
# (18995, 514)
# (18995, 16)

# %%
# sns.scatterplot(x=X['0'], y=Y['LABEL_Heartrate'], hue=Y['LABEL_Sepsis'])
sns.regplot(x=X['0'], y=Y['LABEL_Sepsis'])
# Out:
# <AxesSubplot:xlabel='0', ylabel='LABEL_Sepsis'>

# %%
X["0"].hist(bins=100)
# np.log(X["0"]).hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
for label in ['LABEL_Sepsis']:
# for label in ['LABEL_Heartrate']:
# for label in ['LABEL_SpO2']:
# for label in ['LABEL_Sepsis','LABEL_BaseExcess', 'LABEL_Fibrinogen', 'LABEL_AST', 'LABEL_Alkalinephos', 'LABEL_Bilirubin_total', 'LABEL_Lactate', 'LABEL_TroponinI', 'LABEL_SaO2', 'LABEL_Bilirubin_direct', 'LABEL_EtCO2', 'LABEL_RRate', 'LABEL_ABPm', 'LABEL_SpO2', 'LABEL_Heartrate']:
    X[label] = Y[label]
    cor = X.corr()
    # cor = Y.corr()
    #Correlation with output variable
    # cor_target = abs(cor[label])
    cor_target = cor[label]

    #Selecting highly correlated features
    relevant_features = cor_target[cor_target>-1]
    
    #sort
    # relevant_features.sort_values(inplace=True, ascending=False)

    pd.set_option('display.float_format', lambda x: '%.9f' % x)
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
        print(relevant_features)
    # print(relevant_features)
    # display(relevant_features)
    # print("\n ")

# df["sepsis"] = Y2
# cor = X.corr()
# df.head()
# print(df.shape)
# Out:
# pid                            0.003961791
# Time                           0.026886727
# Age                            0.003397209
# EtCO2_1                        0.046118177
# EtCO2_2                        0.074263531
# EtCO2_3                        0.057892465
# EtCO2_4                        0.111423007
# EtCO2_5                       -0.005890202
# EtCO2_6                        0.038424018
# EtCO2_7                        0.062285845
# EtCO2_8                       -0.033984162
# EtCO2_9                        0.046352839
# EtCO2_10                       0.039248138
# EtCO2_11                       0.087362549
# EtCO2_12                       0.052454558
# PTT_1                          0.030144270
# PTT_2                          0.091591847
# PTT_3                          0.031307409
# PTT_4                         -0.000470209
# PTT_5                          0.033764845
# PTT_6                          0.039533858
# PTT_7                          0.041102750
# PTT_8                         -0.036479330
# PTT_9                          0.064153925
# PTT_10                         0.053094377
# PTT_11                        -0.022874046
# PTT_12                         0.058724723
# BUN_1                          0.023485745
# BUN_2                         -0.010810500
# BUN_3                          0.016974001
# BUN_4                          0.078296417
# BUN_5                          0.038981994
# BUN_6                          0.036635886
# BUN_7                          0.036625053
# BUN_8                          0.007565192
# BUN_9                         -0.074823577
# BUN_10                         0.096274868
# BUN_11                         0.046059300
# BUN_12                         0.074040311
# Lactate_1                      0.057874451
# Lactate_2                      0.110950958
# Lactate_3                     -0.005968705
# Lactate_4                      0.038528804
# Lactate_5                      0.062347972
# Lactate_6                     -0.030907445
# Lactate_7                      0.047378168
# Lactate_8                      0.039272398
# Lactate_9                      0.087362692
# Lactate_10                     0.052620994
# Lactate_11                     0.030133011
# Lactate_12                     0.091571837
# Temp_1                         0.031307826
# Temp_2                        -0.000405788
# Temp_3                         0.033673094
# Temp_4                         0.039940526
# Temp_5                         0.041068629
# Temp_6                        -0.037630965
# Temp_7                         0.064095710
# Temp_8                         0.053482409
# Temp_9                        -0.023090221
# Temp_10                        0.059163166
# Temp_11                        0.023486360
# Temp_12                       -0.010005064
# Hgb_1                          0.016974001
# Hgb_2                          0.078300167
# Hgb_3                          0.039212332
# Hgb_4                          0.037116143
# Hgb_5                          0.036624288
# Hgb_6                          0.007565192
# Hgb_7                         -0.076601096
# Hgb_8                          0.096303400
# Hgb_9                          0.044056080
# Hgb_10                         0.073482955
# Hgb_11                         0.057893673
# Hgb_12                         0.112140201
# HCO3_1                        -0.006424591
# HCO3_2                         0.038289869
# HCO3_3                         0.062700050
# HCO3_4                        -0.026112445
# HCO3_5                         0.049882244
# HCO3_6                         0.039644031
# HCO3_7                         0.087263630
# HCO3_8                         0.052464359
# HCO3_9                         0.030141259
# HCO3_10                        0.091522988
# HCO3_11                        0.031306333
# HCO3_12                       -0.000465071
# BaseExcess_1                   0.033483184
# BaseExcess_2                   0.039789482
# BaseExcess_3                   0.041683561
# BaseExcess_4                  -0.029629438
# BaseExcess_5                   0.064101780
# BaseExcess_6                   0.053048428
# BaseExcess_7                  -0.024963539
# BaseExcess_8                   0.057209220
# BaseExcess_9                   0.023486360
# BaseExcess_10                 -0.002805693
# BaseExcess_11                  0.016974001
# BaseExcess_12                  0.078258532
# RRate_1                        0.038829622
# RRate_2                        0.034996903
# RRate_3                        0.036623468
# RRate_4                        0.007563593
# RRate_5                       -0.074145764
# RRate_6                        0.096387725
# RRate_7                        0.043576355
# RRate_8                        0.072372980
# RRate_9                        0.057643814
# RRate_10                       0.111748408
# RRate_11                      -0.007470548
# RRate_12                       0.037894402
# Fibrinogen_1                   0.063060453
# Fibrinogen_2                  -0.021208908
# Fibrinogen_3                   0.044009820
# Fibrinogen_4                   0.039853726
# Fibrinogen_5                   0.086674153
# Fibrinogen_6                   0.052073221
# Fibrinogen_7                   0.030086902
# Fibrinogen_8                   0.090798604
# Fibrinogen_9                   0.031606811
# Fibrinogen_10                 -0.000502645
# Fibrinogen_11                  0.033299402
# Fibrinogen_12                  0.039984385
# Phosphate_1                    0.041753803
# Phosphate_2                   -0.030707203
# Phosphate_3                    0.064509067
# Phosphate_4                    0.052116941
# Phosphate_5                   -0.023932622
# Phosphate_6                    0.058980203
# Phosphate_7                    0.023585635
# Phosphate_8                    0.000716967
# Phosphate_9                    0.016971216
# Phosphate_10                   0.078274589
# Phosphate_11                   0.038367223
# Phosphate_12                   0.036245379
# WBC_1                          0.036744298
# WBC_2                          0.007483529
# WBC_3                         -0.080265030
# WBC_4                          0.096434866
# WBC_5                          0.043722018
# WBC_6                          0.072845364
# WBC_7                          0.057756578
# WBC_8                          0.112489373
# WBC_9                         -0.007519202
# WBC_10                         0.038181286
# WBC_11                         0.063375012
# WBC_12                        -0.021053663
# Creatinine_1                   0.038044517
# Creatinine_2                   0.040107740
# Creatinine_3                   0.085894655
# Creatinine_4                   0.051745695
# Creatinine_5                   0.030317951
# Creatinine_6                   0.087967352
# Creatinine_7                   0.031733647
# Creatinine_8                   0.127256341
# Creatinine_9                   0.033045399
# Creatinine_10                  0.039207955
# Creatinine_11                  0.041885485
# Creatinine_12                 -0.032246920
# PaCO2_1                        0.065106124
# PaCO2_2                        0.050949021
# PaCO2_3                       -0.022682108
# PaCO2_4                        0.057174210
# PaCO2_5                        0.023583390
# PaCO2_6                       -0.002115920
# PaCO2_7                        0.016884600
# PaCO2_8                        0.078278917
# PaCO2_9                        0.038368811
# PaCO2_10                       0.034772243
# PaCO2_11                       0.037069865
# PaCO2_12                       0.007465720
# AST_1                         -0.075675820
# AST_2                          0.096558335
# AST_3                          0.045177549
# AST_4                          0.073766159
# AST_5                          0.057958943
# AST_6                          0.115154892
# AST_7                         -0.007885642
# AST_8                          0.038220543
# AST_9                          0.063447016
# AST_10                        -0.021186781
# AST_11                         0.033126244
# AST_12                         0.039785309
# FiO2_1                         0.085630921
# FiO2_2                         0.051125422
# FiO2_3                         0.030437662
# FiO2_4                         0.088533592
# FiO2_5                         0.031864336
# FiO2_6                         0.128918973
# FiO2_7                         0.032975138
# FiO2_8                         0.038725617
# FiO2_9                         0.042157207
# FiO2_10                       -0.034117515
# FiO2_11                        0.064919117
# FiO2_12                        0.050551980
# Platelets_1                   -0.026211154
# Platelets_2                    0.058908452
# Platelets_3                    0.023471335
# Platelets_4                    0.007579690
# Platelets_5                    0.016903519
# Platelets_6                    0.078401964
# Platelets_7                    0.038374700
# Platelets_8                    0.031196974
# Platelets_9                    0.037117740
# Platelets_10                   0.007270208
# Platelets_11                  -0.079122323
# Platelets_12                   0.096513047
# SaO2_1                         0.045677684
# SaO2_2                         0.071732027
# SaO2_3                         0.058526825
# SaO2_4                         0.112787435
# SaO2_5                        -0.008013142
# SaO2_6                         0.038396507
# SaO2_7                         0.063177844
# SaO2_8                        -0.020033588
# SaO2_9                         0.033566290
# SaO2_10                        0.040411238
# SaO2_11                        0.085110267
# SaO2_12                        0.050873177
# Glucose_1                      0.030830784
# Glucose_2                      0.088153028
# Glucose_3                      0.032261362
# Glucose_4                      0.130614630
# Glucose_5                      0.032845800
# Glucose_6                      0.039914034
# Glucose_7                      0.041805434
# Glucose_8                     -0.024143620
# Glucose_9                      0.064843906
# Glucose_10                     0.050311647
# Glucose_11                    -0.023513893
# Glucose_12                     0.060107065
# ABPm_1                         0.023512413
# ABPm_2                         0.002494911
# ABPm_3                         0.017480857
# ABPm_4                         0.078425626
# ABPm_5                         0.038294964
# ABPm_6                         0.026475889
# ABPm_7                         0.037180976
# ABPm_8                         0.007214000
# ABPm_9                        -0.077661671
# ABPm_10                        0.096547239
# ABPm_11                        0.045718577
# ABPm_12                        0.071350500
# Magnesium_1                    0.059161561
# Magnesium_2                    0.112464324
# Magnesium_3                   -0.007565248
# Magnesium_4                    0.038009725
# Magnesium_5                    0.063332550
# Magnesium_6                   -0.019762880
# Magnesium_7                    0.028235659
# Magnesium_8                    0.041074281
# Magnesium_9                    0.084956092
# Magnesium_10                   0.050541269
# Magnesium_11                   0.031232522
# Magnesium_12                   0.088921157
# Potassium_1                    0.033435623
# Potassium_2                    0.128419278
# Potassium_3                    0.032303823
# Potassium_4                    0.039844869
# Potassium_5                    0.042604765
# Potassium_6                   -0.036924394
# Potassium_7                    0.066543174
# Potassium_8                    0.050641995
# Potassium_9                   -0.026821493
# Potassium_10                   0.058857747
# Potassium_11                   0.023518082
# Potassium_12                   0.015003457
# ABPd_1                         0.017384537
# ABPd_2                         0.078372687
# ABPd_3                         0.038326482
# ABPd_4                         0.026280791
# ABPd_5                         0.037078661
# ABPd_6                         0.006407793
# ABPd_7                        -0.087672535
# ABPd_8                         0.096536328
# ABPd_9                         0.045797412
# ABPd_10                        0.072007953
# ABPd_11                        0.059441974
# ABPd_12                        0.109652930
# Calcium_1                     -0.007836213
# Calcium_2                      0.038677701
# Calcium_3                      0.063498616
# Calcium_4                     -0.016801097
# Calcium_5                      0.029509436
# Calcium_6                      0.041319566
# Calcium_7                      0.084942757
# Calcium_8                      0.049517703
# Calcium_9                      0.031652228
# Calcium_10                     0.088558961
# Calcium_11                     0.034304246
# Calcium_12                     0.126345014
# Alkalinephos_1                 0.032419721
# Alkalinephos_2                 0.040918941
# Alkalinephos_3                 0.044549271
# Alkalinephos_4                -0.023838284
# Alkalinephos_5                 0.066387183
# Alkalinephos_6                 0.051755387
# Alkalinephos_7                -0.019639903
# Alkalinephos_8                 0.058177999
# Alkalinephos_9                 0.023893457
# Alkalinephos_10                0.011554255
# Alkalinephos_11                0.017785836
# Alkalinephos_12                0.078429895
# SpO2_1                         0.039239429
# SpO2_2                         0.027671288
# SpO2_3                         0.038227391
# SpO2_4                         0.006419122
# SpO2_5                        -0.078809568
# SpO2_6                         0.096586773
# SpO2_7                         0.046035873
# SpO2_8                         0.074001056
# SpO2_9                         0.059824805
# SpO2_10                        0.108478389
# SpO2_11                       -0.008072338
# SpO2_12                        0.038953448
# Bilirubin_direct_1             0.063560022
# Bilirubin_direct_2            -0.016840517
# Bilirubin_direct_3             0.036012838
# Bilirubin_direct_4             0.042403865
# Bilirubin_direct_5             0.085644443
# Bilirubin_direct_6             0.049189301
# Bilirubin_direct_7             0.031390824
# Bilirubin_direct_8             0.087153617
# Bilirubin_direct_9             0.035420349
# Bilirubin_direct_10            0.126858869
# Bilirubin_direct_11            0.032279646
# Bilirubin_direct_12            0.041270475
# Chloride_1                     0.042730302
# Chloride_2                    -0.024262854
# Chloride_3                     0.069648627
# Chloride_4                     0.051772323
# Chloride_5                    -0.021152627
# Chloride_6                     0.058160314
# Chloride_7                     0.024000744
# Chloride_8                     0.010261645
# Chloride_9                     0.017770841
# Chloride_10                    0.078649003
# Chloride_11                    0.039175744
# Chloride_12                    0.030941674
# Hct_1                          0.038076351
# Hct_2                          0.006301104
# Hct_3                         -0.078534572
# Hct_4                          0.096630217
# Hct_5                          0.045155620
# Hct_6                          0.071959986
# Hct_7                          0.060127025
# Hct_8                          0.108338472
# Hct_9                         -0.007677478
# Hct_10                         0.038588279
# Hct_11                         0.063539310
# Hct_12                        -0.016513899
# Heartrate_1                    0.032642679
# Heartrate_2                    0.042951814
# Heartrate_3                    0.085741839
# Heartrate_4                    0.048726587
# Heartrate_5                    0.031615322
# Heartrate_6                    0.086329356
# Heartrate_7                    0.035674762
# Heartrate_8                    0.125227069
# Heartrate_9                    0.031227070
# Heartrate_10                   0.040698644
# Heartrate_11                   0.042868751
# Heartrate_12                  -0.021949871
# Bilirubin_total_1              0.070368530
# Bilirubin_total_2              0.050990935
# Bilirubin_total_3             -0.023177622
# Bilirubin_total_4              0.059192204
# Bilirubin_total_5              0.023960799
# Bilirubin_total_6              0.008579781
# Bilirubin_total_7              0.018123105
# Bilirubin_total_8              0.078788382
# Bilirubin_total_9              0.039351164
# Bilirubin_total_10             0.035065829
# Bilirubin_total_11             0.038588448
# Bilirubin_total_12             0.004662506
# TroponinI_1                   -0.080093993
# TroponinI_2                    0.096644509
# TroponinI_3                    0.045623164
# TroponinI_4                    0.072452777
# TroponinI_5                    0.059991002
# TroponinI_6                    0.106792711
# TroponinI_7                   -0.008301827
# TroponinI_8                    0.038371300
# TroponinI_9                    0.063678258
# TroponinI_10                  -0.013042186
# TroponinI_11                   0.031950653
# TroponinI_12                   0.044287353
# ABPs_1                         0.085116418
# ABPs_2                         0.051246047
# ABPs_3                         0.031904671
# ABPs_4                         0.087033843
# ABPs_5                         0.035338506
# ABPs_6                         0.125591035
# ABPs_7                         0.031071315
# ABPs_8                         0.040798767
# ABPs_9                         0.048245380
# ABPs_10                       -0.020470409
# ABPs_11                        0.071181145
# ABPs_12                        0.051103809
# pH_1                          -0.020477288
# pH_2                           0.058404443
# pH_3                           0.023730489
# pH_4                           0.014691711
# pH_5                           0.018169061
# pH_6                           0.078837894
# pH_7                           0.039987104
# pH_8                           0.028990284
# pH_9                           0.038458714
# pH_10                          0.004394670
# pH_11                         -0.073997259
# pH_12                          0.096634080
# EtCO2_ratio                    0.009289831
# PTT_ratio                     -0.001507622
# BUN_ratio                     -0.002128122
# Lactate_ratio                  0.001733466
# Temp_ratio                     0.003323640
# Hgb_ratio                      0.003520457
# HCO3_ratio                    -0.005496096
# BaseExcess_ratio               0.016329191
# RRate_ratio                    0.002193556
# Fibrinogen_ratio              -0.001435683
# Phosphate_ratio               -0.009761192
# WBC_ratio                      0.001563129
# Creatinine_ratio              -0.012382285
# PaCO2_ratio                   -0.003000415
# AST_ratio                     -0.003880550
# FiO2_ratio                    -0.006558785
# Platelets_ratio                0.019140922
# SaO2_ratio                    -0.001909634
# Glucose_ratio                 -0.011606437
# ABPm_ratio                    -0.004622088
# Magnesium_ratio               -0.024199018
# Potassium_ratio               -0.006499852
# ABPd_ratio                    -0.004461265
# Calcium_ratio                 -0.000415213
# Alkalinephos_ratio            -0.004873940
# SpO2_ratio                     0.008009810
# Bilirubin_direct_ratio         0.007806524
# Chloride_ratio                 0.009139282
# Hct_ratio                      0.009099776
# Heartrate_ratio                0.002294092
# Bilirubin_total_ratio          0.001828416
# TroponinI_ratio                0.007208670
# ABPs_ratio                    -0.007907862
# pH_ratio                       0.007915240
# EtCO2_derivative               0.007727792
# PTT_derivative                -0.006525874
# BUN_derivative                -0.001894442
# Lactate_derivative            -0.004976229
# Temp_derivative                0.003960243
# Hgb_derivative                 0.004758477
# HCO3_derivative               -0.007440576
# BaseExcess_derivative          0.006235558
# RRate_derivative               0.014622758
# Fibrinogen_derivative          0.000923703
# Phosphate_derivative          -0.013350312
# WBC_derivative                 0.007998343
# Creatinine_derivative         -0.000849865
# PaCO2_derivative              -0.006490834
# AST_derivative                -0.005596344
# FiO2_derivative                0.001692299
# Platelets_derivative           0.000000617
# SaO2_derivative               -0.004335946
# Glucose_derivative            -0.012672582
# ABPm_derivative               -0.008522338
# Magnesium_derivative          -0.025838755
# Potassium_derivative          -0.002324426
# ABPd_derivative               -0.004311775
# Calcium_derivative            -0.002742134
# Alkalinephos_derivative       -0.002923157
# SpO2_derivative                0.009932303
# Bilirubin_direct_derivative    0.006856785
# Chloride_derivative            0.011145194
# Hct_derivative                 0.010272793
# Heartrate_derivative           0.000038578
# Bilirubin_total_derivative     0.002508631
# TroponinI_derivative           0.002331433
# ABPs_derivative               -0.008791785
# pH_derivative                  0.008223847
# EtCO2_count                    0.005014564
# PTT_count                     -0.000865311
# BUN_count                      0.000608345
# Lactate_count                  0.006199042
# Temp_count                     0.006303829
# Hgb_count                      0.005553207
# HCO3_count                     0.000609126
# BaseExcess_count               0.010346744
# RRate_count                    0.008183617
# Fibrinogen_count               0.007038730
# Phosphate_count               -0.002486090
# WBC_count                     -0.001980741
# Creatinine_count              -0.002175395
# PaCO2_count                    0.011444552
# AST_count                      0.004334603
# FiO2_count                     0.005749798
# Platelets_count               -0.007435931
# SaO2_count                     0.012225329
# Glucose_count                  0.013640861
# ABPm_count                     0.001748479
# Magnesium_count                0.003354670
# Potassium_count                0.003276501
# ABPd_count                     0.010650731
# Calcium_count                 -0.000981147
# Alkalinephos_count             0.004353848
# SpO2_count                     0.007675069
# Bilirubin_direct_count        -0.001207559
# Chloride_count                 0.000181962
# Hct_count                      0.005035297
# Heartrate_count                0.007928978
# Bilirubin_total_count          0.005188069
# TroponinI_count               -0.000555619
# ABPs_count                     0.007379678
# pH_count                       0.011530343
# 0                             -0.074986630
# LABEL_Sepsis                   1.000000000
# Name: LABEL_Sepsis, dtype: float64

# %%
from sklearn.feature_selection import mutual_info_regression

def make_mi_scores(X, y):
    mi_scores = mutual_info_regression(X, y)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(X, Y['LABEL_Sepsis'])
mi_scores
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5448/2624880444.py in <module>
#       7     return mi_scores
#       8
# ----> 9 mi_scores = make_mi_scores(X, Y['LABEL_Sepsis'])
#      10 mi_scores
#
# ~\AppData\Local\Temp/ipykernel_5448/2624880444.py in make_mi_scores(X, y)
#       2
#       3 def make_mi_scores(X, y):
# ----> 4     mi_scores = mutual_info_regression(X, y)
#       5     mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
#       6     mi_scores = mi_scores.sort_values(ascending=False)
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py in mutual_info_regression(X, y, discrete_features, n_neighbors, copy, random_state)
#     382            of a Random Vector", Probl. Peredachi Inf., 23:2 (1987), 9-16
#     383     """
# --> 384     return _estimate_mi(X, y, discrete_features, False, n_neighbors, copy, random_state)
#     385
#     386
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state)
#     298         y += 1e-10 * np.maximum(1, np.mean(np.abs(y))) * rng.randn(n_samples)
#     299
# --> 300     mi = [
#     301         _compute_mi(x, y, discrete_feature, discrete_target, n_neighbors)
#     302         for x, discrete_feature in zip(_iterate_columns(X), discrete_mask)
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py in <listcomp>(.0)
#     299
#     300     mi = [
# --> 301         _compute_mi(x, y, discrete_feature, discrete_target, n_neighbors)
#     302         for x, discrete_feature in zip(_iterate_columns(X), discrete_mask)
#     303     ]
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _compute_mi(x, y, x_discrete, y_discrete, n_neighbors)
#     164         return _compute_mi_cd(x, y, n_neighbors)
#     165     else:
# --> 166         return _compute_mi_cc(x, y, n_neighbors)
#     167
#     168
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _compute_mi_cc(x, y, n_neighbors)
#      65
#      66     kd = KDTree(y, metric="chebyshev")
# ---> 67     ny = kd.query_radius(y, radius, count_only=True, return_distance=False)
#      68     ny = np.array(ny) - 1.0
#      69
#
# KeyboardInterrupt:

# %%
mi_scores
# Out:
# LABEL_Sepsis    0.212523
# ABPs_6          0.019662
# Hgb_11          0.017857
# Temp_2          0.016963
# WBC_12          0.016746
#                   ...
# Chloride_9      0.000000
# RRate_12        0.000000
# Hct_2           0.000000
# Hct_5           0.000000
# pid             0.000000
# Name: MI Scores, Length: 515, dtype: float64

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
# cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()
